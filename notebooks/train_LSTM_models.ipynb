# %%
import os
import json
import numpy as np
import torch
import random
import logging
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from train import LSTMLMTrainer, VAETrainer

with open("Liu_Kheyer_Retrosynthesis_Data/reproduced/v2.4/config.json", "r", encoding="utf-8") as file:
    config = json.load(file)
    config = {
        param: value for _, params in config.items() for param, value in params.items()
    }
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[logging.FileHandler(config["log_path"]),
                              logging.StreamHandler()])

config["cuda"] = config["cuda"] and torch.cuda.is_available()

logging.info(json.dumps(config, indent=4))

# fix seeds
torch.manual_seed(config["seed"])
torch.use_deterministic_algorithms(True)
np.random.seed(config["seed"])
random.seed(config["seed"])
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'

if config["cuda"]:
    logging.info("Using Cuda")
    torch.cuda.manual_seed(config["seed"])
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

if config["mode"] == "train":
    if config["model"] == "LSTM":
        logging.info("training LSTM")
        trainer = LSTMLMTrainer(config=config)
    elif config["model"] == "VAE":
        logging.info("training VAE")
        trainer = VAETrainer(config=config)
    trainer.train()

# %%
import os
import json
import numpy as np
import torch
import random
import logging
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from train import LSTMLMTrainer, VAETrainer

with open("Liu_Kheyer_Retrosynthesis_Data/reproduced/v2.3/config.json", "r", encoding="utf-8") as file:
    config = json.load(file)
    config = {
        param: value for _, params in config.items() for param, value in params.items()
    }
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[logging.FileHandler(config["log_path"]),
                              logging.StreamHandler()])

config["cuda"] = config["cuda"] and torch.cuda.is_available()

logging.info(json.dumps(config, indent=4))

# fix seeds
torch.manual_seed(config["seed"])
torch.use_deterministic_algorithms(True)
np.random.seed(config["seed"])
random.seed(config["seed"])
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'

if config["cuda"]:
    logging.info("Using Cuda")
    torch.cuda.manual_seed(config["seed"])
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

if config["mode"] == "train":
    if config["model"] == "LSTM":
        logging.info("training LSTM")
        trainer = LSTMLMTrainer(config=config)
    elif config["model"] == "VAE":
        logging.info("training VAE")
        trainer = VAETrainer(config=config)
    trainer.train()

# %%
import os
import json
import numpy as np
import torch
import random
import logging
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from train import LSTMLMTrainer, VAETrainer

with open("Liu_Kheyer_Retrosynthesis_Data/reproduced/v2.2/config.json", "r", encoding="utf-8") as file:
    config = json.load(file)
    config = {
        param: value for _, params in config.items() for param, value in params.items()
    }
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[logging.FileHandler(config["log_path"]),
                              logging.StreamHandler()])

config["cuda"] = config["cuda"] and torch.cuda.is_available()

logging.info(json.dumps(config, indent=4))

# fix seeds
torch.manual_seed(config["seed"])
torch.use_deterministic_algorithms(True)
np.random.seed(config["seed"])
random.seed(config["seed"])
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'

if config["cuda"]:
    logging.info("Using Cuda")
    torch.cuda.manual_seed(config["seed"])
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

if config["mode"] == "train":
    if config["model"] == "LSTM":
        logging.info("training LSTM")
        trainer = LSTMLMTrainer(config=config)
    elif config["model"] == "VAE":
        logging.info("training VAE")
        trainer = VAETrainer(config=config)
    trainer.train()
# Out:
# 2025-06-23 11:45:26,969 - INFO - {
#     "save_path": "model_weights/synthesizer/reproduced/v2.2",
#     "main_dir": "Liu_Kheyer_Retrosynthesis_Data",
#     "data_ref_path": "train_ref_dataset.csv",
#     "train_path": "Liu_Kheyer_Retrosynthesis_Data/train/train_targets_ids_200.data",
#     "val_path": "Liu_Kheyer_Retrosynthesis_Data/validation/validation_targets_ids_200.data",
#     "gene_path": "Liu_Kheyer_Retrosynthesis_Data/reproduced/v2.2/gene.data",
#     "log_path": "Liu_Kheyer_Retrosynthesis_Data/reproduced/v2.2/train.log",
#     "load_path": "",
#     "model": "LSTM",
#     "mode": "train",
#     "seed": 42,
#     "n_gen_samples": 10000,
#     "cuda": true,
#     "vocab_size": 56,
#     "batch_size": 256,
#     "seq_len": 200,
#     "epochs": 200,
#     "LSTM_lr": 0.001,
#     "LSTM_embed_dim": 64,
#     "LSTM_hidden_dim": 256,
#     "LSTM_num_layers": 2,
#     "LSTM_dropout_prob": 0.5
# }
# 2025-06-23 11:45:26,972 - INFO - Using Cuda
# 2025-06-23 11:45:26,973 - INFO - training LSTM
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=Liu_Kheyer_Retrosynthesis_Data/vocab2.txt --model_prefix=m  --user_defined_symbols=[BOS],[EOS],[PAD],. --vocab_size=56 --bos_id=-1 --eos_id=-1
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Liu_Kheyer_Retrosynthesis_Data/vocab2.txt
#   input_format:
#   model_prefix: m
#   model_type: UNIGRAM
#   vocab_size: 56
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: [BOS]
#   user_defined_symbols: [EOS]
#   user_defined_symbols: [PAD]
#   user_defined_symbols: .
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: -1
#   eos_id: -1
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: Liu_Kheyer_Retrosynthesis_Data/vocab2.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 53 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [BOS]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [EOS]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [PAD]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: .
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=106
# trainer_interface.cc(560) LOG(INFO) Alphabet size=51
# trainer_interface.cc(561) LOG(INFO) Final character coverage=1
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 53 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=10
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 51 seed sentencepieces
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 53
# trainer_interface.cc(609) LOG(INFO) Done! 51
# unigram_model_trainer.cc(602) LOG(INFO) Using 51 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=51 obj=5.8652 num_tokens=102 num_tokens/piece=2
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=51 obj=6.44429 num_tokens=102 num_tokens/piece=2
# trainer_interface.cc(687) LOG(INFO) Saving model: m.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: m.vocab
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=Liu_Kheyer_Retrosynthesis_Data/vocab2.txt --model_prefix=m  --user_defined_symbols=[BOS],[EOS],[PAD],. --vocab_size=56 --bos_id=-1 --eos_id=-1
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Liu_Kheyer_Retrosynthesis_Data/vocab2.txt
#   input_format:
#   model_prefix: m
#   model_type: UNIGRAM
#   vocab_size: 56
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: [BOS]
#   user_defined_symbols: [EOS]
#   user_defined_symbols: [PAD]
#   user_defined_symbols: .
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: -1
#   eos_id: -1
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: Liu_Kheyer_Retrosynthesis_Data/vocab2.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 53 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [BOS]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [EOS]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [PAD]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: .
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=106
# trainer_interface.cc(560) LOG(INFO) Alphabet size=51
# trainer_interface.cc(561) LOG(INFO) Final character coverage=1
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 53 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=10
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 51 seed sentencepieces
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 53
# trainer_interface.cc(609) LOG(INFO) Done! 51
# unigram_model_trainer.cc(602) LOG(INFO) Using 51 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=51 obj=5.8652 num_tokens=102 num_tokens/piece=2
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=51 obj=6.44429 num_tokens=102 num_tokens/piece=2
# trainer_interface.cc(687) LOG(INFO) Saving model: m.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: m.vocab
# 2025-06-23 11:45:31,745 - INFO - #####################################################
# 2025-06-23 11:45:31,746 - INFO - Start training generator with MLE...
# 2025-06-23 11:45:31,746 - INFO - #####################################################
#
# 2025-06-23 11:45:35,482 - INFO - val loss:  2.2388
# 2025-06-23 11:45:35,485 - INFO - Epoch 0, Train Loss: 2.64561, Val Loss: 2.23878
# 2025-06-23 11:45:42,006 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:45:42,007 - INFO - Seed 42: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:45:48,657 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:45:48,658 - INFO - Seed 0: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:45:56,665 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:45:56,667 - INFO - Seed 250: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:46:03,343 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:46:03,345 - INFO - Seed 1000: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:46:09,655 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:46:09,656 - INFO - Seed 350: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:46:09,656 - INFO -
# Summary Statistics:
# 2025-06-23 11:46:09,657 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:46:09,657 - INFO - JSS                       0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,658 - INFO - Similarity                0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,658 - INFO - String Similarity         0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,659 - INFO - Validity                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,659 - INFO - Novelty Percentage        0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,660 - INFO - Unique Percentage         0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,660 - INFO - Average Inter Dissimilarity 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,661 - INFO - Overall Validity          0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,661 - INFO - Normalized Vendi Score    0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,662 - INFO - Normalized Vendi Score (q=0.1) 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,663 - INFO - Normalized Vendi Score (q=inf) 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,664 - INFO - Avg Normalized Vendi Score Per Class 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,665 - INFO - Filter 1                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,665 - INFO - Filter 2                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,666 - INFO - Filter 3                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:09,666 - INFO - Filter 4                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:12,944 - INFO - val loss:  1.4988
# 2025-06-23 11:46:12,946 - INFO - Epoch 1, Train Loss: 1.85781, Val Loss: 1.49877
# 2025-06-23 11:46:19,821 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:46:19,822 - INFO - Seed 42: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:46:26,694 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:46:26,695 - INFO - Seed 0: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:46:34,482 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:46:34,483 - INFO - Seed 250: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:46:40,783 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:46:40,785 - INFO - Seed 1000: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:46:47,066 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:46:47,067 - INFO - Seed 350: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:46:47,068 - INFO -
# Summary Statistics:
# 2025-06-23 11:46:47,068 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:46:47,069 - INFO - JSS                       0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,069 - INFO - Similarity                0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,069 - INFO - String Similarity         0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,070 - INFO - Validity                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,071 - INFO - Novelty Percentage        0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,071 - INFO - Unique Percentage         0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,072 - INFO - Average Inter Dissimilarity 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,072 - INFO - Overall Validity          0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,073 - INFO - Normalized Vendi Score    0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,073 - INFO - Normalized Vendi Score (q=0.1) 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,074 - INFO - Normalized Vendi Score (q=inf) 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,074 - INFO - Avg Normalized Vendi Score Per Class 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,075 - INFO - Filter 1                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,075 - INFO - Filter 2                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,076 - INFO - Filter 3                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:47,077 - INFO - Filter 4                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:46:51,304 - INFO - val loss:  1.2455
# 2025-06-23 11:46:51,307 - INFO - Epoch 2, Train Loss: 1.44936, Val Loss: 1.24546
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:46:58,771 - INFO - Seed 42: JSS=0.2165, Sim=0.1042, StrSim=0.8289, Val=0.0004, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# 2025-06-23 11:47:05,349 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:47:05,351 - INFO - Seed 0: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:47:13,242 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:47:13,244 - INFO - Seed 250: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:47:19,375 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:47:19,376 - INFO - Seed 1000: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:26,584 - INFO - Seed 350: JSS=0.2165, Sim=0.1096, StrSim=0.8969, Val=0.0001, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# 2025-06-23 11:47:26,585 - INFO -
# Summary Statistics:
# 2025-06-23 11:47:26,585 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:47:26,585 - INFO - JSS                       0.0866   0.1061   0.0000   0.2165
# 2025-06-23 11:47:26,586 - INFO - Similarity                0.0428   0.0524   0.0000   0.1096
# 2025-06-23 11:47:26,586 - INFO - String Similarity         0.3452   0.4233   0.0000   0.8969
# 2025-06-23 11:47:26,586 - INFO - Validity                  0.0001   0.0002   0.0000   0.0004
# 2025-06-23 11:47:26,587 - INFO - Novelty Percentage        0.4000   0.4899   0.0000   1.0000
# 2025-06-23 11:47:26,587 - INFO - Unique Percentage         0.4000   0.4899   0.0000   1.0000
# 2025-06-23 11:47:26,588 - INFO - Average Inter Dissimilarity nan      nan      nan      nan
# 2025-06-23 11:47:26,588 - INFO - Overall Validity          0.0000   0.0000   0.0000   0.0001
# 2025-06-23 11:47:26,588 - INFO - Normalized Vendi Score    0.4000   0.4899   0.0000   1.0000
# 2025-06-23 11:47:26,589 - INFO - Normalized Vendi Score (q=0.1) 0.4000   0.4899   0.0000   1.0000
# 2025-06-23 11:47:26,589 - INFO - Normalized Vendi Score (q=inf) 0.4000   0.4899   0.0000   1.0000
# 2025-06-23 11:47:26,589 - INFO - Avg Normalized Vendi Score Per Class 0.4000   0.4899   0.0000   1.0000
# 2025-06-23 11:47:26,590 - INFO - Filter 1                  0.2500   0.3873   0.0000   1.0000
# 2025-06-23 11:47:26,590 - INFO - Filter 2                  0.4000   0.4899   0.0000   1.0000
# 2025-06-23 11:47:26,590 - INFO - Filter 3                  0.4000   0.4899   0.0000   1.0000
# 2025-06-23 11:47:26,591 - INFO - Filter 4                  0.4000   0.4899   0.0000   1.0000
# 2025-06-23 11:47:30,001 - INFO - val loss:  1.1198
# 2025-06-23 11:47:30,003 - INFO - Epoch 3, Train Loss: 1.27752, Val Loss: 1.11980
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:37,982 - INFO - Seed 42: JSS=0.3377, Sim=0.1195, StrSim=0.8564, Val=0.0008, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9805, OverallVal=0.0002,
#             NVS=0.9998, NVS(q=0.1)=1.0000, NVS(q=inf)=0.9809, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:45,588 - INFO - Seed 0: JSS=0.2938, Sim=0.1583, StrSim=0.8598, Val=0.0004, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9439, OverallVal=0.0002,
#             NVS=0.9984, NVS(q=0.1)=0.9998, NVS(q=inf)=0.9469, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:54,446 - INFO - Seed 250: JSS=0.2680, Sim=0.1346, StrSim=0.8747, Val=0.0008, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:01,611 - INFO - Seed 1000: JSS=0.2165, Sim=0.2439, StrSim=0.8376, Val=0.0008, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# 2025-06-23 11:48:08,119 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:48:08,120 - INFO - Seed 350: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:48:08,121 - INFO -
# Summary Statistics:
# 2025-06-23 11:48:08,121 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:48:08,122 - INFO - JSS                       0.2232   0.1183   0.0000   0.3377
# 2025-06-23 11:48:08,122 - INFO - Similarity                0.1313   0.0785   0.0000   0.2439
# 2025-06-23 11:48:08,123 - INFO - String Similarity         0.6857   0.3431   0.0000   0.8747
# 2025-06-23 11:48:08,123 - INFO - Validity                  0.0006   0.0003   0.0000   0.0008
# 2025-06-23 11:48:08,123 - INFO - Novelty Percentage        0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:48:08,124 - INFO - Unique Percentage         0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:48:08,124 - INFO - Average Inter Dissimilarity nan      nan      nan      nan
# 2025-06-23 11:48:08,125 - INFO - Overall Validity          0.0001   0.0001   0.0000   0.0002
# 2025-06-23 11:48:08,125 - INFO - Normalized Vendi Score    0.7996   0.3998   0.0000   1.0000
# 2025-06-23 11:48:08,126 - INFO - Normalized Vendi Score (q=0.1) 0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:48:08,126 - INFO - Normalized Vendi Score (q=inf) 0.7856   0.3933   0.0000   1.0000
# 2025-06-23 11:48:08,127 - INFO - Avg Normalized Vendi Score Per Class 0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:48:08,127 - INFO - Filter 1                  0.3500   0.2151   0.0000   0.6250
# 2025-06-23 11:48:08,128 - INFO - Filter 2                  0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:48:08,128 - INFO - Filter 3                  0.4733   0.3505   0.0000   1.0000
# 2025-06-23 11:48:08,128 - INFO - Filter 4                  0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:48:11,486 - INFO - val loss:  1.0450
# 2025-06-23 11:48:11,489 - INFO - Epoch 4, Train Loss: 1.17880, Val Loss: 1.04498
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:19,294 - INFO - Seed 42: JSS=0.4958, Sim=0.0826, StrSim=0.8674, Val=0.0029, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9795, OverallVal=0.0003,
#             NVS=0.9995, NVS(q=0.1)=1.0000, NVS(q=inf)=0.9600, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:27,444 - INFO - Seed 0: JSS=0.4934, Sim=0.1071, StrSim=0.8632, Val=0.0031, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9587, OverallVal=0.0007,
#             NVS=0.9940, NVS(q=0.1)=0.9994, NVS(q=inf)=0.7923, AvgNVSPerClass=0.9999
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:36,775 - INFO - Seed 250: JSS=0.5294, Sim=0.1266, StrSim=0.8853, Val=0.0027, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9668, OverallVal=0.0005,
#             NVS=0.9973, NVS(q=0.1)=0.9997, NVS(q=inf)=0.8760, AvgNVSPerClass=0.9996
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:44,434 - INFO - Seed 1000: JSS=0.3252, Sim=0.1681, StrSim=0.8606, Val=0.0023, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9636, OverallVal=0.0004,
#             NVS=0.9976, NVS(q=0.1)=0.9998, NVS(q=inf)=0.8985, AvgNVSPerClass=0.9992
