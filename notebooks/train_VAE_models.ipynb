# %%
import os
import json
import numpy as np
import torch
import random
import logging
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from train import LSTMLMTrainer, VAETrainer

with open("Liu_Kheyer_Retrosynthesis_Data/reproduced/v4/config.json", "r", encoding="utf-8") as file:
    config = json.load(file)
    config = {
        param: value for _, params in config.items() for param, value in params.items()
    }
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[logging.FileHandler(config["log_path"]),
                              logging.StreamHandler()])

config["cuda"] = config["cuda"] and torch.cuda.is_available()

logging.info(json.dumps(config, indent=4))

# fix seeds
torch.manual_seed(config["seed"])
torch.use_deterministic_algorithms(True)
np.random.seed(config["seed"])
random.seed(config["seed"])
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'

if config["cuda"]:
    logging.info("Using Cuda")
    torch.cuda.manual_seed(config["seed"])
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

if config["mode"] == "train":
    if config["model"] == "LSTM":
        logging.info("training LSTM")
        trainer = LSTMLMTrainer(config=config)
    elif config["model"] == "VAE":
        logging.info("training VAE")
        trainer = VAETrainer(config=config)
    trainer.train()

# %%
import os
import json
import numpy as np
import torch
import random
import logging
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from train import LSTMLMTrainer, VAETrainer

with open("Liu_Kheyer_Retrosynthesis_Data/reproduced/v4.3/config.json", "r", encoding="utf-8") as file:
    config = json.load(file)
    config = {
        param: value for _, params in config.items() for param, value in params.items()
    }
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[logging.FileHandler(config["log_path"]),
                              logging.StreamHandler()])

config["cuda"] = config["cuda"] and torch.cuda.is_available()

logging.info(json.dumps(config, indent=4))

# fix seeds
torch.manual_seed(config["seed"])
torch.use_deterministic_algorithms(True)
np.random.seed(config["seed"])
random.seed(config["seed"])
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'

if config["cuda"]:
    logging.info("Using Cuda")
    torch.cuda.manual_seed(config["seed"])
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

if config["mode"] == "train":
    if config["model"] == "LSTM":
        logging.info("training LSTM")
        trainer = LSTMLMTrainer(config=config)
    elif config["model"] == "VAE":
        logging.info("training VAE")
        trainer = VAETrainer(config=config)
    trainer.train()

# %%
import os
import json
import numpy as np
import torch
import random
import logging
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from train import LSTMLMTrainer, VAETrainer

with open("Liu_Kheyer_Retrosynthesis_Data/reproduced/v2.4/config.json", "r", encoding="utf-8") as file:
    config = json.load(file)
    config = {
        param: value for _, params in config.items() for param, value in params.items()
    }
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[logging.FileHandler(config["log_path"]),
                              logging.StreamHandler()])

config["cuda"] = config["cuda"] and torch.cuda.is_available()

logging.info(json.dumps(config, indent=4))

# fix seeds
torch.manual_seed(config["seed"])
torch.use_deterministic_algorithms(True)
np.random.seed(config["seed"])
random.seed(config["seed"])
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'

if config["cuda"]:
    logging.info("Using Cuda")
    torch.cuda.manual_seed(config["seed"])
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

if config["mode"] == "train":
    if config["model"] == "LSTM":
        logging.info("training LSTM")
        trainer = LSTMLMTrainer(config=config)
    elif config["model"] == "VAE":
        logging.info("training VAE")
        trainer = VAETrainer(config=config)
    trainer.train()

# %%
import os
import json
import numpy as np
import torch
import random
import logging
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from train import LSTMLMTrainer, VAETrainer

with open("Liu_Kheyer_Retrosynthesis_Data/reproduced/v2/config.json", "r", encoding="utf-8") as file:
    config = json.load(file)
    config = {
        param: value for _, params in config.items() for param, value in params.items()
    }
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[logging.FileHandler(config["log_path"]),
                              logging.StreamHandler()])

config["cuda"] = config["cuda"] and torch.cuda.is_available()

logging.info(json.dumps(config, indent=4))

# fix seeds
torch.manual_seed(config["seed"])
torch.use_deterministic_algorithms(True)
np.random.seed(config["seed"])
random.seed(config["seed"])
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'

if config["cuda"]:
    logging.info("Using Cuda")
    torch.cuda.manual_seed(config["seed"])
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

if config["mode"] == "train":
    if config["model"] == "LSTM":
        logging.info("training LSTM")
        trainer = LSTMLMTrainer(config=config)
    elif config["model"] == "VAE":
        logging.info("training VAE")
        trainer = VAETrainer(config=config)
    trainer.train()
# Out:
# 2025-06-23 11:43:12,470 - INFO - {
#     "save_path": "model_weights/synthesizer/reproduced/v2",
#     "main_dir": "Liu_Kheyer_Retrosynthesis_Data",
#     "data_ref_path": "train_ref_dataset.csv",
#     "train_path": "Liu_Kheyer_Retrosynthesis_Data/train/train_targets_ids_200.data",
#     "val_path": "Liu_Kheyer_Retrosynthesis_Data/validation/validation_targets_ids_200.data",
#     "gene_path": "Liu_Kheyer_Retrosynthesis_Data/reproduced/v2/gene.data",
#     "log_path": "Liu_Kheyer_Retrosynthesis_Data/reproduced/v2/train.log",
#     "load_path": "",
#     "model": "LSTM",
#     "mode": "train",
#     "seed": 42,
#     "n_gen_samples": 10000,
#     "cuda": true,
#     "vocab_size": 56,
#     "batch_size": 256,
#     "seq_len": 200,
#     "epochs": 200,
#     "LSTM_lr": 0.001,
#     "LSTM_embed_dim": 64,
#     "LSTM_hidden_dim": 256,
#     "LSTM_num_layers": 1,
#     "LSTM_dropout_prob": 0.5
# }
# 2025-06-23 11:43:12,472 - INFO - Using Cuda
# 2025-06-23 11:43:12,473 - INFO - training LSTM
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=Liu_Kheyer_Retrosynthesis_Data/vocab2.txt --model_prefix=m  --user_defined_symbols=[BOS],[EOS],[PAD],. --vocab_size=56 --bos_id=-1 --eos_id=-1
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Liu_Kheyer_Retrosynthesis_Data/vocab2.txt
#   input_format:
#   model_prefix: m
#   model_type: UNIGRAM
#   vocab_size: 56
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: [BOS]
#   user_defined_symbols: [EOS]
#   user_defined_symbols: [PAD]
#   user_defined_symbols: .
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: -1
#   eos_id: -1
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: Liu_Kheyer_Retrosynthesis_Data/vocab2.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 53 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [BOS]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [EOS]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [PAD]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: .
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=106
# trainer_interface.cc(560) LOG(INFO) Alphabet size=51
# trainer_interface.cc(561) LOG(INFO) Final character coverage=1
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 53 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=10
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 51 seed sentencepieces
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 53
# trainer_interface.cc(609) LOG(INFO) Done! 51
# unigram_model_trainer.cc(602) LOG(INFO) Using 51 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=51 obj=5.8652 num_tokens=102 num_tokens/piece=2
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=51 obj=6.44429 num_tokens=102 num_tokens/piece=2
# trainer_interface.cc(687) LOG(INFO) Saving model: m.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: m.vocab
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/torch/nn/modules/rnn.py:62: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=Liu_Kheyer_Retrosynthesis_Data/vocab2.txt --model_prefix=m  --user_defined_symbols=[BOS],[EOS],[PAD],. --vocab_size=56 --bos_id=-1 --eos_id=-1
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: Liu_Kheyer_Retrosynthesis_Data/vocab2.txt
#   input_format:
#   model_prefix: m
#   model_type: UNIGRAM
#   vocab_size: 56
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: [BOS]
#   user_defined_symbols: [EOS]
#   user_defined_symbols: [PAD]
#   user_defined_symbols: .
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: -1
#   eos_id: -1
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: Liu_Kheyer_Retrosynthesis_Data/vocab2.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 53 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [BOS]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [EOS]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: [PAD]
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: .
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=106
# trainer_interface.cc(560) LOG(INFO) Alphabet size=51
# trainer_interface.cc(561) LOG(INFO) Final character coverage=1
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 53 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=10
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 51 seed sentencepieces
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 53
# trainer_interface.cc(609) LOG(INFO) Done! 51
# unigram_model_trainer.cc(602) LOG(INFO) Using 51 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=51 obj=5.8652 num_tokens=102 num_tokens/piece=2
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=51 obj=6.44429 num_tokens=102 num_tokens/piece=2
# trainer_interface.cc(687) LOG(INFO) Saving model: m.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: m.vocab
# 2025-06-23 11:43:17,839 - INFO - #####################################################
# 2025-06-23 11:43:17,840 - INFO - Start training generator with MLE...
# 2025-06-23 11:43:17,840 - INFO - #####################################################
#
# 2025-06-23 11:43:20,212 - INFO - val loss:  1.9065
# 2025-06-23 11:43:20,215 - INFO - Epoch 0, Train Loss: 2.51116, Val Loss: 1.90647
# 2025-06-23 11:43:27,085 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:43:27,087 - INFO - Seed 42: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:43:33,782 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:43:33,783 - INFO - Seed 0: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:43:41,833 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:43:41,834 - INFO - Seed 250: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:43:47,800 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:43:47,801 - INFO - Seed 1000: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:43:53,511 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:43:53,513 - INFO - Seed 350: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:43:53,513 - INFO -
# Summary Statistics:
# 2025-06-23 11:43:53,514 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:43:53,515 - INFO - JSS                       0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,515 - INFO - Similarity                0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,516 - INFO - String Similarity         0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,517 - INFO - Validity                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,517 - INFO - Novelty Percentage        0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,518 - INFO - Unique Percentage         0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,518 - INFO - Average Inter Dissimilarity 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,519 - INFO - Overall Validity          0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,519 - INFO - Normalized Vendi Score    0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,520 - INFO - Normalized Vendi Score (q=0.1) 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,521 - INFO - Normalized Vendi Score (q=inf) 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,521 - INFO - Avg Normalized Vendi Score Per Class 0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,522 - INFO - Filter 1                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,522 - INFO - Filter 2                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,523 - INFO - Filter 3                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:53,523 - INFO - Filter 4                  0.0000   0.0000   0.0000   0.0000
# 2025-06-23 11:43:56,125 - INFO - val loss:  1.3554
# 2025-06-23 11:43:56,128 - INFO - Epoch 1, Train Loss: 1.62396, Val Loss: 1.35538
# 2025-06-23 11:44:02,243 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:44:02,244 - INFO - Seed 42: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:44:08,230 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:44:08,232 - INFO - Seed 0: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:44:14,343 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:44:14,344 - INFO - Seed 250: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:44:23,246 - INFO - Seed 1000: JSS=0.4166, Sim=0.1314, StrSim=0.8941, Val=0.0001, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# 2025-06-23 11:44:29,846 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:44:29,847 - INFO - Seed 350: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# 2025-06-23 11:44:29,848 - INFO -
# Summary Statistics:
# 2025-06-23 11:44:29,848 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:44:29,848 - INFO - JSS                       0.0833   0.1666   0.0000   0.4166
# 2025-06-23 11:44:29,849 - INFO - Similarity                0.0263   0.0526   0.0000   0.1314
# 2025-06-23 11:44:29,849 - INFO - String Similarity         0.1788   0.3576   0.0000   0.8941
# 2025-06-23 11:44:29,849 - INFO - Validity                  0.0000   0.0000   0.0000   0.0001
# 2025-06-23 11:44:29,850 - INFO - Novelty Percentage        0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:29,850 - INFO - Unique Percentage         0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:29,850 - INFO - Average Inter Dissimilarity nan      nan      nan      nan
# 2025-06-23 11:44:29,852 - INFO - Overall Validity          0.0000   0.0000   0.0000   0.0001
# 2025-06-23 11:44:29,852 - INFO - Normalized Vendi Score    0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:29,852 - INFO - Normalized Vendi Score (q=0.1) 0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:29,853 - INFO - Normalized Vendi Score (q=inf) 0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:29,853 - INFO - Avg Normalized Vendi Score Per Class 0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:29,854 - INFO - Filter 1                  0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:29,854 - INFO - Filter 2                  0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:29,855 - INFO - Filter 3                  0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:29,855 - INFO - Filter 4                  0.2000   0.4000   0.0000   1.0000
# 2025-06-23 11:44:32,156 - INFO - val loss:  1.1757
# 2025-06-23 11:44:32,159 - INFO - Epoch 2, Train Loss: 1.32045, Val Loss: 1.17568
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:44:39,540 - INFO - Seed 42: JSS=0.1929, Sim=0.1014, StrSim=0.8939, Val=0.0007, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:44:47,059 - INFO - Seed 0: JSS=0.2165, Sim=0.1471, StrSim=0.8772, Val=0.0006, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# 2025-06-23 11:44:53,519 - INFO - No Valid Reactions, exiting...
# 2025-06-23 11:44:53,521 - INFO - Seed 250: JSS=0.0000, Sim=0.0000, StrSim=0.0000, Val=0.0000, NoveltyPerc=0.0000,
#             UniquePerc=0.0000, IntDiv=0.0000, OverallVal=0.0000,
#             NVS=0.0000, NVS(q=0.1)=0.0000, NVS(q=inf)=0.0000, AvgNVSPerClass=0.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:45:03,002 - INFO - Seed 1000: JSS=0.3721, Sim=0.1991, StrSim=0.8519, Val=0.0003, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9685, OverallVal=0.0002,
#             NVS=0.9995, NVS(q=0.1)=1.0000, NVS(q=inf)=0.9695, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:45:10,006 - INFO - Seed 350: JSS=0.2680, Sim=0.1011, StrSim=0.8650, Val=0.0004, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# 2025-06-23 11:45:10,007 - INFO -
# Summary Statistics:
# 2025-06-23 11:45:10,007 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:45:10,008 - INFO - JSS                       0.2099   0.1217   0.0000   0.3721
# 2025-06-23 11:45:10,008 - INFO - Similarity                0.1097   0.0657   0.0000   0.1991
# 2025-06-23 11:45:10,009 - INFO - String Similarity         0.6976   0.3491   0.0000   0.8939
# 2025-06-23 11:45:10,010 - INFO - Validity                  0.0004   0.0002   0.0000   0.0007
# 2025-06-23 11:45:10,010 - INFO - Novelty Percentage        0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:45:10,011 - INFO - Unique Percentage         0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:45:10,012 - INFO - Average Inter Dissimilarity nan      nan      nan      nan
# 2025-06-23 11:45:10,012 - INFO - Overall Validity          0.0001   0.0001   0.0000   0.0002
# 2025-06-23 11:45:10,013 - INFO - Normalized Vendi Score    0.7999   0.4000   0.0000   1.0000
# 2025-06-23 11:45:10,014 - INFO - Normalized Vendi Score (q=0.1) 0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:45:10,014 - INFO - Normalized Vendi Score (q=inf) 0.7939   0.3971   0.0000   1.0000
# 2025-06-23 11:45:10,015 - INFO - Avg Normalized Vendi Score Per Class 0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:45:10,015 - INFO - Filter 1                  0.2952   0.2477   0.0000   0.6667
# 2025-06-23 11:45:10,016 - INFO - Filter 2                  0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:45:10,017 - INFO - Filter 3                  0.7000   0.4000   0.0000   1.0000
# 2025-06-23 11:45:10,017 - INFO - Filter 4                  0.8000   0.4000   0.0000   1.0000
# 2025-06-23 11:45:12,174 - INFO - val loss:  1.0974
# 2025-06-23 11:45:12,176 - INFO - Epoch 3, Train Loss: 1.20408, Val Loss: 1.09743
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:45:18,858 - INFO - Seed 42: JSS=0.4523, Sim=0.1378, StrSim=0.8643, Val=0.0014, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=1.0000, OverallVal=0.0002,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# 2025-06-23 11:45:24,906 - INFO - Seed 0: JSS=0.2165, Sim=0.1190, StrSim=0.8402, Val=0.0019, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9828, OverallVal=0.0002,
#             NVS=0.9999, NVS(q=0.1)=1.0000, NVS(q=inf)=0.9831, AvgNVSPerClass=0.9999
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:45:31,146 - INFO - Seed 250: JSS=0.4693, Sim=0.1406, StrSim=0.8630, Val=0.0020, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9792, OverallVal=0.0004,
#             NVS=0.9989, NVS(q=0.1)=0.9999, NVS(q=inf)=0.9310, AvgNVSPerClass=0.9996
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:45:41,074 - INFO - Seed 1000: JSS=0.3913, Sim=0.1622, StrSim=0.8697, Val=0.0012, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9917, OverallVal=0.0004,
#             NVS=0.9997, NVS(q=0.1)=1.0000, NVS(q=inf)=0.9696, AvgNVSPerClass=0.9999
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:45:48,354 - INFO - Seed 350: JSS=0.3265, Sim=0.1324, StrSim=0.9202, Val=0.0013, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# 2025-06-23 11:45:48,355 - INFO -
# Summary Statistics:
# 2025-06-23 11:45:48,356 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:45:48,356 - INFO - JSS                       0.3712   0.0923   0.2165   0.4693
# 2025-06-23 11:45:48,356 - INFO - Similarity                0.1384   0.0140   0.1190   0.1622
# 2025-06-23 11:45:48,357 - INFO - String Similarity         0.8715   0.0264   0.8402   0.9202
# 2025-06-23 11:45:48,357 - INFO - Validity                  0.0016   0.0003   0.0012   0.0020
# 2025-06-23 11:45:48,358 - INFO - Novelty Percentage        1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:45:48,358 - INFO - Unique Percentage         1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:45:48,359 - INFO - Average Inter Dissimilarity nan      nan      nan      nan
# 2025-06-23 11:45:48,359 - INFO - Overall Validity          0.0003   0.0001   0.0001   0.0004
# 2025-06-23 11:45:48,360 - INFO - Normalized Vendi Score    0.9997   0.0004   0.9989   1.0000
# 2025-06-23 11:45:48,360 - INFO - Normalized Vendi Score (q=0.1) 1.0000   0.0000   0.9999   1.0000
# 2025-06-23 11:45:48,361 - INFO - Normalized Vendi Score (q=inf) 0.9767   0.0256   0.9310   1.0000
# 2025-06-23 11:45:48,361 - INFO - Avg Normalized Vendi Score Per Class 0.9999   0.0002   0.9996   1.0000
# 2025-06-23 11:45:48,362 - INFO - Filter 1                  0.2923   0.0753   0.1579   0.3846
# 2025-06-23 11:45:48,362 - INFO - Filter 2                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:45:48,363 - INFO - Filter 3                  0.6067   0.2603   0.2000   1.0000
# 2025-06-23 11:45:48,363 - INFO - Filter 4                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:45:50,673 - INFO - val loss:  1.0425
# 2025-06-23 11:45:50,675 - INFO - Epoch 4, Train Loss: 1.14065, Val Loss: 1.04248
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:45:58,127 - INFO - Seed 42: JSS=0.3524, Sim=0.1384, StrSim=0.8944, Val=0.0013, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=1.0000, OverallVal=0.0002,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:46:05,140 - INFO - Seed 0: JSS=0.4819, Sim=0.1389, StrSim=0.8748, Val=0.0019, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9704, OverallVal=0.0005,
#             NVS=0.9977, NVS(q=0.1)=0.9998, NVS(q=inf)=0.8899, AvgNVSPerClass=0.9994
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:46:12,002 - INFO - Seed 250: JSS=0.2680, Sim=0.0983, StrSim=0.9071, Val=0.0016, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:46:20,305 - INFO - Seed 1000: JSS=0.5670, Sim=0.1770, StrSim=0.8775, Val=0.0025, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9673, OverallVal=0.0006,
#             NVS=0.9948, NVS(q=0.1)=0.9995, NVS(q=inf)=0.8358, AvgNVSPerClass=0.9993
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:46:27,977 - INFO - Seed 350: JSS=0.4692, Sim=0.1033, StrSim=0.8686, Val=0.0021, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9709, OverallVal=0.0003,
#             NVS=0.9992, NVS(q=0.1)=0.9999, NVS(q=inf)=0.9450, AvgNVSPerClass=0.9998
# 2025-06-23 11:46:27,978 - INFO -
# Summary Statistics:
# 2025-06-23 11:46:27,979 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:46:27,979 - INFO - JSS                       0.4277   0.1051   0.2680   0.5670
# 2025-06-23 11:46:27,979 - INFO - Similarity                0.1312   0.0285   0.0983   0.1770
# 2025-06-23 11:46:27,980 - INFO - String Similarity         0.8845   0.0142   0.8686   0.9071
# 2025-06-23 11:46:27,980 - INFO - Validity                  0.0019   0.0004   0.0013   0.0025
# 2025-06-23 11:46:27,981 - INFO - Novelty Percentage        1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:46:27,981 - INFO - Unique Percentage         1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:46:27,982 - INFO - Average Inter Dissimilarity nan      nan      nan      nan
# 2025-06-23 11:46:27,983 - INFO - Overall Validity          0.0003   0.0002   0.0001   0.0006
# 2025-06-23 11:46:27,983 - INFO - Normalized Vendi Score    0.9983   0.0019   0.9948   1.0000
# 2025-06-23 11:46:27,984 - INFO - Normalized Vendi Score (q=0.1) 0.9998   0.0002   0.9995   1.0000
# 2025-06-23 11:46:27,984 - INFO - Normalized Vendi Score (q=inf) 0.9341   0.0639   0.8358   1.0000
# 2025-06-23 11:46:27,984 - INFO - Avg Normalized Vendi Score Per Class 0.9997   0.0003   0.9993   1.0000
# 2025-06-23 11:46:27,985 - INFO - Filter 1                  0.2870   0.0984   0.1538   0.4000
# 2025-06-23 11:46:27,985 - INFO - Filter 2                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:46:27,986 - INFO - Filter 3                  0.6700   0.2829   0.1667   1.0000
# 2025-06-23 11:46:27,986 - INFO - Filter 4                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:46:30,342 - INFO - val loss:  1.0047
# 2025-06-23 11:46:30,345 - INFO - Epoch 5, Train Loss: 1.09466, Val Loss: 1.00471
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:46:37,414 - INFO - Seed 42: JSS=0.3561, Sim=0.1364, StrSim=0.8782, Val=0.0018, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9498, OverallVal=0.0004,
#             NVS=0.9952, NVS(q=0.1)=0.9995, NVS(q=inf)=0.8682, AvgNVSPerClass=0.9998
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:46:44,473 - INFO - Seed 0: JSS=0.2853, Sim=0.0974, StrSim=0.8774, Val=0.0038, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:46:52,448 - INFO - Seed 250: JSS=0.3265, Sim=0.1239, StrSim=0.8651, Val=0.0020, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=nan, OverallVal=0.0001,
#             NVS=1.0000, NVS(q=0.1)=1.0000, NVS(q=inf)=1.0000, AvgNVSPerClass=1.0000
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:46:59,933 - INFO - Seed 1000: JSS=0.4515, Sim=0.1697, StrSim=0.8763, Val=0.0047, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9708, OverallVal=0.0007,
#             NVS=0.9911, NVS(q=0.1)=0.9991, NVS(q=inf)=0.8160, AvgNVSPerClass=0.9993
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:07,153 - INFO - Seed 350: JSS=0.5869, Sim=0.1267, StrSim=0.8836, Val=0.0039, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9745, OverallVal=0.0006,
#             NVS=0.9975, NVS(q=0.1)=0.9998, NVS(q=inf)=0.8797, AvgNVSPerClass=1.0000
# 2025-06-23 11:47:07,154 - INFO -
# Summary Statistics:
# 2025-06-23 11:47:07,154 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:47:07,154 - INFO - JSS                       0.4013   0.1078   0.2853   0.5869
# 2025-06-23 11:47:07,155 - INFO - Similarity                0.1308   0.0233   0.0974   0.1697
# 2025-06-23 11:47:07,155 - INFO - String Similarity         0.8761   0.0061   0.8651   0.8836
# 2025-06-23 11:47:07,156 - INFO - Validity                  0.0032   0.0011   0.0018   0.0047
# 2025-06-23 11:47:07,156 - INFO - Novelty Percentage        1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:47:07,157 - INFO - Unique Percentage         1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:47:07,157 - INFO - Average Inter Dissimilarity nan      nan      nan      nan
# 2025-06-23 11:47:07,158 - INFO - Overall Validity          0.0004   0.0002   0.0001   0.0007
# 2025-06-23 11:47:07,158 - INFO - Normalized Vendi Score    0.9968   0.0034   0.9911   1.0000
# 2025-06-23 11:47:07,159 - INFO - Normalized Vendi Score (q=0.1) 0.9997   0.0003   0.9991   1.0000
# 2025-06-23 11:47:07,159 - INFO - Normalized Vendi Score (q=inf) 0.9128   0.0744   0.8160   1.0000
# 2025-06-23 11:47:07,160 - INFO - Avg Normalized Vendi Score Per Class 0.9998   0.0003   0.9993   1.0000
# 2025-06-23 11:47:07,160 - INFO - Filter 1                  0.3779   0.1384   0.1316   0.5500
# 2025-06-23 11:47:07,161 - INFO - Filter 2                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:47:07,161 - INFO - Filter 3                  0.3176   0.1506   0.0909   0.5000
# 2025-06-23 11:47:07,162 - INFO - Filter 4                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:47:09,441 - INFO - val loss:  0.9729
# 2025-06-23 11:47:09,444 - INFO - Epoch 6, Train Loss: 1.06105, Val Loss: 0.97288
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:16,485 - INFO - Seed 42: JSS=0.4803, Sim=0.1195, StrSim=0.8864, Val=0.0025, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9547, OverallVal=0.0005,
#             NVS=0.9930, NVS(q=0.1)=0.9993, NVS(q=inf)=0.8326, AvgNVSPerClass=0.9996
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:23,494 - INFO - Seed 0: JSS=0.5855, Sim=0.1204, StrSim=0.8777, Val=0.0044, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9607, OverallVal=0.0008,
#             NVS=0.9939, NVS(q=0.1)=0.9994, NVS(q=inf)=0.7802, AvgNVSPerClass=0.9997
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:30,524 - INFO - Seed 250: JSS=0.7764, Sim=0.1146, StrSim=0.8783, Val=0.0047, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9688, OverallVal=0.0010,
#             NVS=0.9941, NVS(q=0.1)=0.9994, NVS(q=inf)=0.7706, AvgNVSPerClass=0.9997
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:38,178 - INFO - Seed 1000: JSS=0.3638, Sim=0.1860, StrSim=0.8796, Val=0.0037, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9597, OverallVal=0.0005,
#             NVS=0.9950, NVS(q=0.1)=0.9995, NVS(q=inf)=0.8432, AvgNVSPerClass=0.9995
# 2025-06-23 11:47:46,009 - INFO - Seed 350: JSS=0.5159, Sim=0.1071, StrSim=0.8745, Val=0.0050, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9554, OverallVal=0.0011,
#             NVS=0.9893, NVS(q=0.1)=0.9990, NVS(q=inf)=0.6846, AvgNVSPerClass=0.9982
# 2025-06-23 11:47:46,010 - INFO -
# Summary Statistics:
# 2025-06-23 11:47:46,010 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:47:46,011 - INFO - JSS                       0.5444   0.1364   0.3638   0.7764
# 2025-06-23 11:47:46,011 - INFO - Similarity                0.1295   0.0286   0.1071   0.1860
# 2025-06-23 11:47:46,012 - INFO - String Similarity         0.8793   0.0039   0.8745   0.8864
# 2025-06-23 11:47:46,012 - INFO - Validity                  0.0041   0.0009   0.0025   0.0050
# 2025-06-23 11:47:46,012 - INFO - Novelty Percentage        1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:47:46,013 - INFO - Unique Percentage         1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:47:46,013 - INFO - Average Inter Dissimilarity 0.9599   0.0051   0.9547   0.9688
# 2025-06-23 11:47:46,014 - INFO - Overall Validity          0.0008   0.0002   0.0005   0.0011
# 2025-06-23 11:47:46,019 - INFO - Normalized Vendi Score    0.9931   0.0020   0.9893   0.9950
# 2025-06-23 11:47:46,020 - INFO - Normalized Vendi Score (q=0.1) 0.9993   0.0002   0.9990   0.9995
# 2025-06-23 11:47:46,021 - INFO - Normalized Vendi Score (q=inf) 0.7822   0.0564   0.6846   0.8432
# 2025-06-23 11:47:46,021 - INFO - Avg Normalized Vendi Score Per Class 0.9993   0.0006   0.9982   0.9997
# 2025-06-23 11:47:46,021 - INFO - Filter 1                  0.3639   0.0737   0.2955   0.4600
# 2025-06-23 11:47:46,022 - INFO - Filter 2                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:47:46,022 - INFO - Filter 3                  0.5299   0.0743   0.4545   0.6250
# 2025-06-23 11:47:46,022 - INFO - Filter 4                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:47:48,285 - INFO - val loss:  0.9423
# 2025-06-23 11:47:48,287 - INFO - Epoch 7, Train Loss: 1.02869, Val Loss: 0.94235
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:47:55,894 - INFO - Seed 42: JSS=0.6991, Sim=0.1327, StrSim=0.8711, Val=0.0092, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9584, OverallVal=0.0013,
#             NVS=0.9887, NVS(q=0.1)=0.9990, NVS(q=inf)=0.6616, AvgNVSPerClass=0.9984
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:03,636 - INFO - Seed 0: JSS=0.5994, Sim=0.1181, StrSim=0.8783, Val=0.0111, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9674, OverallVal=0.0022,
#             NVS=0.9860, NVS(q=0.1)=0.9987, NVS(q=inf)=0.5820, AvgNVSPerClass=0.9972
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:11,049 - INFO - Seed 250: JSS=0.5871, Sim=0.1374, StrSim=0.8866, Val=0.0098, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9605, OverallVal=0.0009,
#             NVS=0.9923, NVS(q=0.1)=0.9993, NVS(q=inf)=0.7486, AvgNVSPerClass=0.9992
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:19,249 - INFO - Seed 1000: JSS=0.6914, Sim=0.1437, StrSim=0.8725, Val=0.0101, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9633, OverallVal=0.0013,
#             NVS=0.9894, NVS(q=0.1)=0.9990, NVS(q=inf)=0.6842, AvgNVSPerClass=0.9986
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:27,294 - INFO - Seed 350: JSS=0.6693, Sim=0.1115, StrSim=0.8698, Val=0.0107, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9641, OverallVal=0.0011,
#             NVS=0.9921, NVS(q=0.1)=0.9993, NVS(q=inf)=0.7262, AvgNVSPerClass=0.9987
# 2025-06-23 11:48:27,294 - INFO -
# Summary Statistics:
# 2025-06-23 11:48:27,295 - INFO - Metric                    Avg      Std      Min      Max
# 2025-06-23 11:48:27,295 - INFO - JSS                       0.6493   0.0469   0.5871   0.6991
# 2025-06-23 11:48:27,296 - INFO - Similarity                0.1287   0.0120   0.1115   0.1437
# 2025-06-23 11:48:27,296 - INFO - String Similarity         0.8757   0.0062   0.8698   0.8866
# 2025-06-23 11:48:27,297 - INFO - Validity                  0.0102   0.0007   0.0092   0.0111
# 2025-06-23 11:48:27,297 - INFO - Novelty Percentage        1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:48:27,298 - INFO - Unique Percentage         1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:48:27,298 - INFO - Average Inter Dissimilarity 0.9628   0.0031   0.9584   0.9674
# 2025-06-23 11:48:27,299 - INFO - Overall Validity          0.0014   0.0004   0.0009   0.0022
# 2025-06-23 11:48:27,300 - INFO - Normalized Vendi Score    0.9897   0.0023   0.9860   0.9923
# 2025-06-23 11:48:27,301 - INFO - Normalized Vendi Score (q=0.1) 0.9990   0.0002   0.9987   0.9993
# 2025-06-23 11:48:27,302 - INFO - Normalized Vendi Score (q=inf) 0.6805   0.0580   0.5820   0.7486
# 2025-06-23 11:48:27,302 - INFO - Avg Normalized Vendi Score Per Class 0.9984   0.0007   0.9972   0.9992
# 2025-06-23 11:48:27,303 - INFO - Filter 1                  0.3436   0.0457   0.2653   0.3804
# 2025-06-23 11:48:27,303 - INFO - Filter 2                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:48:27,304 - INFO - Filter 3                  0.3814   0.0728   0.3235   0.5238
# 2025-06-23 11:48:27,305 - INFO - Filter 4                  1.0000   0.0000   1.0000   1.0000
# 2025-06-23 11:48:30,282 - INFO - val loss:  0.9150
# 2025-06-23 11:48:30,284 - INFO - Epoch 8, Train Loss: 0.99695, Val Loss: 0.91505
# 2025-06-23 11:48:38,185 - INFO - Seed 42: JSS=0.7368, Sim=0.1374, StrSim=0.8772, Val=0.0223, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9610, OverallVal=0.0036,
#             NVS=0.9723, NVS(q=0.1)=0.9976, NVS(q=inf)=0.4127, AvgNVSPerClass=0.9949
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/anis/miniconda3/envs/chemgen_env/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 2025-06-23 11:48:46,068 - INFO - Seed 0: JSS=0.7103, Sim=0.1346, StrSim=0.8747, Val=0.0207, NoveltyPerc=1.0000,
#             UniquePerc=1.0000, IntDiv=0.9643, OverallVal=0.0040,
#             NVS=0.9698, NVS(q=0.1)=0.9974, NVS(q=inf)=0.4022, AvgNVSPerClass=0.9951
